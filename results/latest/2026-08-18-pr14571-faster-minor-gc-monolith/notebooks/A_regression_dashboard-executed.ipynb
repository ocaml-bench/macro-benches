# %% [markdown]
# # A — Regression Dashboard
#
# **Audience:** anyone asking *"did this compiler change regress or improve the benchmarks?"*
#
# **Structure (Option C — per-comparison).** Every section under §4 corresponds to one comparison block declared in `runbms.yml` (or supplied via `COMPARISONS_OVERRIDE`). Each block is a self-contained story: instruction-count deltas, wall-time and max-RSS tornado plots per pair, a tradeoff scatter restricted to the block's variants, and ranked top-N regressions/improvements.
#
# When `runbms.yml` declares no `comparisons:` block, the loader falls back to a single default block (`BASELINE` vs every other variant) — the rendered output is then equivalent to a traditional single-baseline view.
#
# Configuration knobs are in the next cell. See [README.md §5.6](./README.md) for the YAML schema.

# %%
# Configuration — edit here, or override with BENCH_LOGS_DIR.
import os
from pathlib import Path

LOGS_DIR = Path(os.environ.get("BENCH_LOGS_DIR")
                or "../gc-sweep-logs/<SET-BENCH_LOGS_DIR>")
BASELINE = {"version": "trunk-cfb30145", "flags": "baseline"}
TOP_N    = 10
WARN_PCT = 1.0       # instruction-count verdict thresholds
REGRESS_PCT = 3.0

# When not None, ignore the runbms.yml `comparisons:` block and use this
# Python list instead. Same shape as the YAML schema. Useful for ad-hoc
# exploration without editing YAML or re-running benchmarks.
COMPARISONS_OVERRIDE = None
# Example:
# COMPARISONS_OVERRIDE = [
#     {"label": "flambda only", "a": "ocaml-5.4.1", "b": "ocaml-5.4.1-flambda"},
# ]

# Benchmarks to exclude from all graphs/tables (e.g. outliers that
# distort the scale).  The notebook still loads them; they just don't
# appear in plots.  Set to e.g. ["liq_video_frames_pool"] for the
# PR-14796 sweep, where its non-default-(s, o) cells thrash the GC and
# the resulting wide range of medians makes the tornado plots
# unreadable.
EXCLUDE_BENCHES: list[str] = []

CACHE = Path.cwd() / "cache" / "macrobench.parquet"
if not LOGS_DIR.exists():
    raise SystemExit(
        f"LOGS_DIR does not exist: {LOGS_DIR.resolve()}\n"
        "Set BENCH_LOGS_DIR to your run directory, e.g.:\n"
        "  BENCH_LOGS_DIR=../gc-sweep-logs/monolith-2026-05-07-Thu-110013 jupyter ...\n"
        "or edit this cell."
    )
print("LOGS_DIR =", LOGS_DIR.resolve())
print("BASELINE =", BASELINE)
print("COMPARISONS_OVERRIDE =", COMPARISONS_OVERRIDE)
# Out:
# LOGS_DIR = /home/udesou/macro-benches/results/latest/2026-08-18-pr14571-faster-minor-gc-monolith/logs/main
# BASELINE = {'version': 'trunk-cfb30145', 'flags': 'baseline'}
# COMPARISONS_OVERRIDE = None

# %%
# %matplotlib inline
import sys
sys.path.insert(0, str(Path.cwd()))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display, Markdown

from macrobench_loader import (
    load_macro_dataframe, load_comparisons, audit_comparison_coverage,
    instruction_count_deltas,
)

pd.set_option("display.max_columns", 80)
pd.set_option("display.width", 160)

# %% [markdown]
# ## 1. Load
#
# Parses every `.log` + `olly_*.json` + `perf_*.json` in `LOGS_DIR` and writes a parquet cache. Subsequent runs read the cache. Delete `cache/macrobench.parquet` to force a rebuild.

# %%
if CACHE.exists():
    df = pd.read_parquet(CACHE)
    print(f"Loaded cache: {CACHE}  shape={df.shape}")
else:
    df = load_macro_dataframe(LOGS_DIR)
    CACHE.parent.mkdir(exist_ok=True)
    df.to_parquet(CACHE)
    print(f"Built cache:  {CACHE}  shape={df.shape}")

variants = sorted(df["variant"].unique())
if EXCLUDE_BENCHES:
    df = df[~df["benchmark"].isin(EXCLUDE_BENCHES)].reset_index(drop=True)
benches  = sorted(df["benchmark"].unique())
print(f"{len(benches)} benchmarks × {len(variants)} variants")
print("variants:", variants)
# Out:
# Built cache:  /home/udesou/macro-benches/results/latest/2026-08-18-pr14571-faster-minor-gc-monolith/notebooks/cache/macrobench.parquet  shape=(380, 50)
# 38 benchmarks × 2 variants
# variants: ['pr14571/baseline', 'trunk-3b14dfbc/baseline']

# %% [markdown]
# ## 2. Sanity & schema
#
# Three checks before any plotting:
#
# 1. **Completeness** — for every (benchmark, variant) cell, how many invocations were recorded?
# 2. **NaN audit** — which metric columns are partially or fully empty?
# 3. **Schema sanity** — does every declared runtime have data, and is every loaded variant rendered by some comparison block?

# %%
completeness = df.pivot_table(
    index="benchmark", columns="variant",
    values="olly_wall_time_s", aggfunc="count",
).fillna(0).astype(int)

print(f"Completeness: {(completeness > 0).sum().sum()} / {completeness.size} cells populated")
print(f"Invocations per cell: min={completeness.values.min()}  max={completeness.values.max()}")
missing = completeness[(completeness == 0).any(axis=1)]
if not missing.empty:
    print("\nBenchmarks with missing variants:")
    print(missing)

fig, ax = plt.subplots(figsize=(1.2 * len(variants) + 2, max(3, 0.3 * len(benches))))
vmax = max(completeness.values.max(), 1)
im = ax.imshow(completeness.values, aspect="auto", cmap="Greens", vmin=0, vmax=vmax)
ax.set_xticks(range(len(completeness.columns)))
ax.set_xticklabels(completeness.columns, rotation=60, ha="right")
ax.set_yticks(range(len(completeness.index)))
ax.set_yticklabels(completeness.index)
for (i, j), v in np.ndenumerate(completeness.values):
    ax.text(j, i, str(v), ha="center", va="center", fontsize=8,
            color="white" if v >= vmax / 2 else "black")
ax.set_title("Invocations per (benchmark, variant)")
fig.colorbar(im, ax=ax, label="invocations", shrink=0.7)
plt.tight_layout()
plt.show()
completeness
# Out:
# Completeness: 76 / 76 cells populated
# Invocations per cell: min=5  max=5
# variant                        pr14571/baseline  trunk-3b14dfbc/baseline
# benchmark
# alt_ergo_chain_default                        5                        5
# alt_ergo_chain_large                          5                        5
# coqc_tree_default                             5                        5
# coqc_tree_large                               5                        5
# cpdf_squeeze_default                          5                        5
# cpdf_squeeze_large                            5                        5
# devkit_htmlstream_default                     5                        5
# devkit_htmlstream_large                       5                        5
# eio_conc_default                              5                        5
# eio_conc_large                                5                        5
# frama_c_eva_sqlite_default                    5                        5
# frama_c_eva_sqlite_large                      5                        5
# irmin_mem_rw_default                          5                        5
# irmin_mem_rw_large                            5                        5
# jsoo_default                                  5                        5
# jsoo_large                                    5                        5
# liq_parse_typecheck_default                   5                        5
# liq_parse_typecheck_large                     5                        5
# liq_video_frames_pool_default                 5                        5
# liq_video_frames_pool_large                   5                        5
# menhir_ocamly                                 5                        5
# menhir_sysver_canonical                       5                        5
# ocamlc_compile_uucp_default                   5                        5
# ocamlc_compile_uucp_large                     5                        5
# ocamlformat_rocq_default                      5                        5
# ocamlformat_rocq_large                        5                        5
# owl_gc_default                                5                        5
# owl_gc_large                                  5                        5
# pplacer_like_default                          5                        5
# pplacer_like_large                            5                        5
# sedlex_tokenize_default                       5                        5
# sedlex_tokenize_large                         5                        5
# test_decompress_default                       5                        5
# test_decompress_large                         5                        5
# ydump_repeat_default                          5                        5
# ydump_repeat_large                            5                        5
# zarith_pi_default                             5                        5
# zarith_pi_large                               5                        5

# %%
# NaN audit
nan_counts = df.isna().sum().sort_values(ascending=False)
nan_counts[nan_counts > 0].head(20)
# Out:
# s                         380
# re                        380
# o                         380
# md                        380
# M                         380
# m                         380
# gc_params_extra           380
# perf_page-faults_sec      332
# perf_page-faults_k_sec     48
# dtype: int64

# %%
# Resolve comparisons (from YAML or override) and audit schema coverage.
comparisons = load_comparisons(
    LOGS_DIR, all_variants=variants,
    baseline=BASELINE, override=COMPARISONS_OVERRIDE,
)
audit = audit_comparison_coverage(LOGS_DIR, df, comparisons)

print("Comparisons declared:")
for c in comparisons:
    print(f"  - {c.label!r}  ({len(c.pairs)} pair{'s' if len(c.pairs) != 1 else ''})")

print(
    f"\nVariant coverage: {audit.comparison_variants_total} / "
    f"{audit.data_variants_total} data variants are referenced by a comparison block."
)
if audit.declared_runtimes_no_data:
    print(
        "\nWARNING: runtimes declared in `runbms.yml runtimes:` but no data "
        "present in the dataset:\n  " + ", ".join(audit.declared_runtimes_no_data)
    )
    print("  → Likely declared but not referenced by any `configs:` entry, "
          "or the run failed for these.")
if audit.data_variants_uncovered:
    print(
        "\nWARNING: variants loaded from the dataset but not rendered by any "
        "comparison block:\n  " + ", ".join(audit.data_variants_uncovered)
    )
    print("  → Add a comparison block (or COMPARISONS_OVERRIDE) that mentions them, "
          "or accept the omission.")
# Out:
# Comparisons declared:
#   - 'faster minor GC PR vs trunk merge-base'  (1 pair)
#
# Variant coverage: 2 / 2 data variants are referenced by a comparison block.

# %% [markdown]
# ## 3. Comparisons overview
#
# One row per declared comparison block, summarising regression/improvement counts and worst/best wall-time Δ. Use this to decide which block in §4 to read first.

# %%
def _delta_per_bench(df, av, bv, metric):
    """Δ% per benchmark for the median ratio of (b vs a)."""
    a = df[df["variant"] == av].groupby("benchmark")[metric].median()
    b = df[df["variant"] == bv].groupby("benchmark")[metric].median()
    return ((b / a) - 1.0).dropna() * 100.0


overview_rows = []
for cmp in comparisons:
    deltas = []
    for av, bv in cmp.pairs:
        d = _delta_per_bench(df, av, bv, "olly_wall_time_s")
        deltas.extend(d.values)
    deltas = np.array(deltas)
    if deltas.size == 0:
        overview_rows.append({"block": cmp.label, "pairs": len(cmp.pairs),
                              "datapoints": 0, "regressions ≥1%": 0,
                              "improvements ≤−1%": 0, "worst Δ%": np.nan,
                              "best Δ%": np.nan})
        continue
    overview_rows.append({
        "block": cmp.label,
        "pairs": len(cmp.pairs),
        "datapoints": deltas.size,
        "regressions ≥1%":  int((deltas >=  WARN_PCT).sum()),
        "improvements ≤−1%": int((deltas <= -WARN_PCT).sum()),
        "worst Δ%": round(float(deltas.max()), 2),
        "best Δ%":  round(float(deltas.min()), 2),
    })
overview = pd.DataFrame(overview_rows)
overview
# Out:
#                                     block  pairs  datapoints  regressions ≥1%  improvements ≤−1%  worst Δ%  best Δ%
# 0  faster minor GC PR vs trunk merge-base      1          38                5                 20     32.47    -4.26

# %% [markdown]
# ## 4. Per-comparison detail
#
# One subsection per comparison block. The cell below defines small render helpers; the next cell loops them across every block.

# %%
def _tornado_grid(cmp, df, metric, metric_label, benches):
    n_pairs = len(cmp.pairs)
    if n_pairs == 0:
        return
    ncols = min(2, n_pairs)
    nrows = (n_pairs + ncols - 1) // ncols
    height = max(3.0, 0.22 * len(benches)) * nrows + 0.5
    fig, axes = plt.subplots(nrows, ncols, figsize=(7.2 * ncols, height), squeeze=False)
    for (av, bv), ax in zip(cmp.pairs, axes.flat):
        d = _delta_per_bench(df, av, bv, metric).reindex(benches).dropna().sort_values()
        if d.empty:
            ax.text(0.5, 0.5, "no data", ha="center", va="center", transform=ax.transAxes)
            ax.set_title(f"{av}  →  {bv}", fontsize=10)
            continue
        colors = ["#2a9d8f" if x < 0 else "#e76f51" for x in d.values]
        ax.barh(d.index, d.values, color=colors)
        ax.axvline(0, color="black", linewidth=0.7)
        ax.set_title(f"{av}  →  {bv}", fontsize=10)
        ax.set_xlabel(f"{metric_label} Δ%", fontsize=8)
        ax.tick_params(axis="y", labelsize=7)
    for ax in axes.flat[n_pairs:]:
        ax.axis("off")
    fig.suptitle(f"{cmp.label} — {metric_label}", y=1.00, fontsize=11)
    plt.tight_layout()
    plt.show()


def _ranked_block_table(cmp, df, metric, metric_label, top_n):
    rows = []
    for av, bv in cmp.pairs:
        d = _delta_per_bench(df, av, bv, metric)
        for bench, v in d.items():
            rows.append({"benchmark": bench, "a": av, "b": bv, f"{metric_label}_Δ%": round(v, 3)})
    if not rows:
        print(f"  ({metric_label}: no resolvable data)")
        return
    summary = pd.DataFrame(rows)
    print(f"\n{metric_label}: top {top_n} regressions")
    print(summary.sort_values(f"{metric_label}_Δ%", ascending=False).head(top_n).to_string(index=False))
    print(f"\n{metric_label}: top {top_n} improvements")
    print(summary.sort_values(f"{metric_label}_Δ%").head(top_n).to_string(index=False))


def _instruction_count_table(cmp, df, top_n, warn_pct, regress_pct):
    if "perf_instructions" not in df.columns or df["perf_instructions"].isna().all():
        print("  (perf_instructions not available — skipping)")
        return
    rows = []
    for av, bv in cmp.pairs:
        d = _delta_per_bench(df, av, bv, "perf_instructions")
        for bench, v in d.items():
            verdict = (
                "improvement" if v <= -regress_pct
                else "regression" if v >=  regress_pct
                else "warn"        if abs(v) >= warn_pct
                else "neutral"
            )
            rows.append({"benchmark": bench, "a": av, "b": bv,
                         "instructions Δ%": round(v, 3), "verdict": verdict})
    if not rows:
        print("  (no data)")
        return
    t = pd.DataFrame(rows).sort_values("instructions Δ%", ascending=False)
    counts = t["verdict"].value_counts().to_dict()
    print(f"  Verdict counts: {counts}")
    print(f"\n  top {top_n} regressions")
    print(t.head(top_n).to_string(index=False))
    print(f"\n  top {top_n} improvements")
    print(t.tail(top_n).iloc[::-1].to_string(index=False))


def _tradeoff_scatter_block(cmp, df):
    if "max_rss_mb" not in df.columns or df["max_rss_mb"].isna().all():
        print("  (max_rss_mb not available — skipping tradeoff scatter)")
        return
    rows = []
    for av, bv in cmp.pairs:
        wall_d = _delta_per_bench(df, av, bv, "olly_wall_time_s")
        rss_d  = _delta_per_bench(df, av, bv, "max_rss_mb")
        common = wall_d.index.intersection(rss_d.index)
        for bench in common:
            rows.append({"benchmark": bench, "pair": f"{av} → {bv}",
                         "wall_ratio": 1.0 + wall_d[bench] / 100.0,
                         "rss_ratio":  1.0 + rss_d[bench]  / 100.0})
    if not rows:
        print("  (tradeoff: no rows)")
        return
    pts = pd.DataFrame(rows)
    pairs_unique = sorted(pts["pair"].unique())
    fig, ax = plt.subplots(figsize=(8, 7))
    palette = plt.colormaps["tab10"].resampled(max(len(pairs_unique), 10))
    for i, p in enumerate(pairs_unique):
        sub = pts[pts["pair"] == p]
        ax.scatter(sub["wall_ratio"], sub["rss_ratio"], color=palette(i), label=p, alpha=0.75, s=35)
    ax.axhline(1.0, color="gray", linewidth=0.5, linestyle="--")
    ax.axvline(1.0, color="gray", linewidth=0.5, linestyle="--")
    ax.set_xlabel("wall time ratio  (b / a)")
    ax.set_ylabel("max RSS ratio  (b / a)")
    ax.set_title(f"{cmp.label} — time × memory tradeoff")
    ax.legend(loc="center left", bbox_to_anchor=(1.02, 0.5), frameon=False, fontsize=9)
    plt.tight_layout()
    plt.show()


def render_block(cmp, df, benches, top_n=10, warn_pct=1.0, regress_pct=3.0):
    display(Markdown(f"### {cmp.label}"))
    pair_lines = "\n".join(f"- `{a}`  →  `{b}`" for a, b in cmp.pairs)
    display(Markdown(f"**Pairs ({len(cmp.pairs)}):**\n\n{pair_lines}"))

    display(Markdown("#### Instruction-count Δ%"))
    _instruction_count_table(cmp, df, top_n, warn_pct, regress_pct)

    display(Markdown("#### Wall-time Δ% per pair"))
    _tornado_grid(cmp, df, "olly_wall_time_s", "wall time", benches)

    display(Markdown("#### Max RSS Δ% per pair"))
    _tornado_grid(cmp, df, "max_rss_mb", "max RSS", benches)

    if "olly_p95_latency_ms" in df.columns and df["olly_p95_latency_ms"].notna().any():
        display(Markdown("#### p95 latency Δ% per pair"))
        _tornado_grid(cmp, df, "olly_p95_latency_ms", "p95 latency", benches)
    if "olly_p99_latency_ms" in df.columns and df["olly_p99_latency_ms"].notna().any():
        display(Markdown("#### p99 latency Δ% per pair"))
        _tornado_grid(cmp, df, "olly_p99_latency_ms", "p99 latency", benches)

    display(Markdown("#### Time × memory tradeoff"))
    _tradeoff_scatter_block(cmp, df)

    display(Markdown("#### Ranked tables (within block)"))
    for metric, label in (
        ("olly_wall_time_s", "wall"),
        ("max_rss_mb", "rss"),
        ("olly_gc_overhead_pct", "gc_overhead"),
    ):
        if metric not in df.columns or df[metric].isna().all():
            continue
        _ranked_block_table(cmp, df, metric, label, top_n)
    print()  # spacing

# %%
for cmp in comparisons:
    render_block(cmp, df, benches, top_n=TOP_N,
                 warn_pct=WARN_PCT, regress_pct=REGRESS_PCT)
# Out:
# ### faster minor GC PR vs trunk merge-base
# **Pairs (1):**
#
# - `trunk-3b14dfbc/baseline`  →  `pr14571/baseline`
# #### Instruction-count Δ%
#   Verdict counts: {'neutral': 16, 'improvement': 13, 'warn': 8, 'regression': 1}
#
#   top 10 regressions
#                     benchmark                       a                b  instructions Δ%    verdict
#                owl_gc_default trunk-3b14dfbc/baseline pr14571/baseline           23.434 regression
#                  owl_gc_large trunk-3b14dfbc/baseline pr14571/baseline            0.819    neutral
#      frama_c_eva_sqlite_large trunk-3b14dfbc/baseline pr14571/baseline            0.257    neutral
#             zarith_pi_default trunk-3b14dfbc/baseline pr14571/baseline            0.013    neutral
#       test_decompress_default trunk-3b14dfbc/baseline pr14571/baseline            0.013    neutral
#            pplacer_like_large trunk-3b14dfbc/baseline pr14571/baseline            0.006    neutral
#             coqc_tree_default trunk-3b14dfbc/baseline pr14571/baseline            0.001    neutral
#               coqc_tree_large trunk-3b14dfbc/baseline pr14571/baseline           -0.001    neutral
# liq_video_frames_pool_default trunk-3b14dfbc/baseline pr14571/baseline           -0.002    neutral
#   liq_video_frames_pool_large trunk-3b14dfbc/baseline pr14571/baseline           -0.002    neutral
#
#   top 10 improvements
#                   benchmark                       a                b  instructions Δ%     verdict
#            eio_conc_default trunk-3b14dfbc/baseline pr14571/baseline           -5.648 improvement
#              eio_conc_large trunk-3b14dfbc/baseline pr14571/baseline           -5.558 improvement
#                  jsoo_large trunk-3b14dfbc/baseline pr14571/baseline           -4.814 improvement
#     sedlex_tokenize_default trunk-3b14dfbc/baseline pr14571/baseline           -4.775 improvement
#                jsoo_default trunk-3b14dfbc/baseline pr14571/baseline           -4.756 improvement
#       sedlex_tokenize_large trunk-3b14dfbc/baseline pr14571/baseline           -4.710 improvement
# liq_parse_typecheck_default trunk-3b14dfbc/baseline pr14571/baseline           -4.411 improvement
#   liq_parse_typecheck_large trunk-3b14dfbc/baseline pr14571/baseline           -3.681 improvement
#        ydump_repeat_default trunk-3b14dfbc/baseline pr14571/baseline           -3.213 improvement
#          ydump_repeat_large trunk-3b14dfbc/baseline pr14571/baseline           -3.207 improvement
# #### Wall-time Δ% per pair
# #### Max RSS Δ% per pair
# #### p95 latency Δ% per pair
# #### p99 latency Δ% per pair
# #### Time × memory tradeoff
# #### Ranked tables (within block)
# wall: top 10 regressions
#                     benchmark                       a                b  wall_Δ%
#                owl_gc_default trunk-3b14dfbc/baseline pr14571/baseline   32.469
#       test_decompress_default trunk-3b14dfbc/baseline pr14571/baseline    2.773
#         test_decompress_large trunk-3b14dfbc/baseline pr14571/baseline    2.384
#            pplacer_like_large trunk-3b14dfbc/baseline pr14571/baseline    1.324
#   liq_video_frames_pool_large trunk-3b14dfbc/baseline pr14571/baseline    1.105
#      frama_c_eva_sqlite_large trunk-3b14dfbc/baseline pr14571/baseline    0.292
#               zarith_pi_large trunk-3b14dfbc/baseline pr14571/baseline    0.260
#       devkit_htmlstream_large trunk-3b14dfbc/baseline pr14571/baseline    0.213
#             coqc_tree_default trunk-3b14dfbc/baseline pr14571/baseline    0.158
# liq_video_frames_pool_default trunk-3b14dfbc/baseline pr14571/baseline   -0.141
#
# wall: top 10 improvements
#                   benchmark                       a                b  wall_Δ%
# liq_parse_typecheck_default trunk-3b14dfbc/baseline pr14571/baseline   -4.255
#   liq_parse_typecheck_large trunk-3b14dfbc/baseline pr14571/baseline   -4.222
#            eio_conc_default trunk-3b14dfbc/baseline pr14571/baseline   -4.181
#     sedlex_tokenize_default trunk-3b14dfbc/baseline pr14571/baseline   -3.492
#              eio_conc_large trunk-3b14dfbc/baseline pr14571/baseline   -3.201
#          cpdf_squeeze_large trunk-3b14dfbc/baseline pr14571/baseline   -3.129
#          ydump_repeat_large trunk-3b14dfbc/baseline pr14571/baseline   -3.113
#                  jsoo_large trunk-3b14dfbc/baseline pr14571/baseline   -2.672
#                jsoo_default trunk-3b14dfbc/baseline pr14571/baseline   -2.603
#        pplacer_like_default trunk-3b14dfbc/baseline pr14571/baseline   -2.530
#
# rss: top 10 regressions
#                     benchmark                       a                b  rss_Δ%
#     liq_parse_typecheck_large trunk-3b14dfbc/baseline pr14571/baseline   7.190
#   liq_parse_typecheck_default trunk-3b14dfbc/baseline pr14571/baseline   5.686
#     devkit_htmlstream_default trunk-3b14dfbc/baseline pr14571/baseline   1.191
#                owl_gc_default trunk-3b14dfbc/baseline pr14571/baseline   0.848
#            irmin_mem_rw_large trunk-3b14dfbc/baseline pr14571/baseline   0.631
#      ocamlformat_rocq_default trunk-3b14dfbc/baseline pr14571/baseline   0.148
#          cpdf_squeeze_default trunk-3b14dfbc/baseline pr14571/baseline   0.123
#            cpdf_squeeze_large trunk-3b14dfbc/baseline pr14571/baseline   0.093
# liq_video_frames_pool_default trunk-3b14dfbc/baseline pr14571/baseline   0.047
#                  owl_gc_large trunk-3b14dfbc/baseline pr14571/baseline   0.038
#
# rss: top 10 improvements
#                  benchmark                       a                b  rss_Δ%
#    devkit_htmlstream_large trunk-3b14dfbc/baseline pr14571/baseline  -5.954
#            zarith_pi_large trunk-3b14dfbc/baseline pr14571/baseline  -3.672
#          zarith_pi_default trunk-3b14dfbc/baseline pr14571/baseline  -2.063
#              menhir_ocamly trunk-3b14dfbc/baseline pr14571/baseline  -0.746
#  ocamlc_compile_uucp_large trunk-3b14dfbc/baseline pr14571/baseline  -0.520
# frama_c_eva_sqlite_default trunk-3b14dfbc/baseline pr14571/baseline  -0.227
#       irmin_mem_rw_default trunk-3b14dfbc/baseline pr14571/baseline  -0.188
#               jsoo_default trunk-3b14dfbc/baseline pr14571/baseline  -0.188
#    test_decompress_default trunk-3b14dfbc/baseline pr14571/baseline  -0.126
#      test_decompress_large trunk-3b14dfbc/baseline pr14571/baseline  -0.029
#
# gc_overhead: top 10 regressions
#                     benchmark                       a                b  gc_overhead_Δ%
#                  owl_gc_large trunk-3b14dfbc/baseline pr14571/baseline          14.766
#          pplacer_like_default trunk-3b14dfbc/baseline pr14571/baseline           3.333
#                owl_gc_default trunk-3b14dfbc/baseline pr14571/baseline           2.751
#               zarith_pi_large trunk-3b14dfbc/baseline pr14571/baseline           1.598
#   liq_video_frames_pool_large trunk-3b14dfbc/baseline pr14571/baseline           0.294
#             zarith_pi_default trunk-3b14dfbc/baseline pr14571/baseline           0.103
#             coqc_tree_default trunk-3b14dfbc/baseline pr14571/baseline           0.053
# liq_video_frames_pool_default trunk-3b14dfbc/baseline pr14571/baseline           0.044
#               coqc_tree_large trunk-3b14dfbc/baseline pr14571/baseline          -0.052
#                eio_conc_large trunk-3b14dfbc/baseline pr14571/baseline          -1.411
#
# gc_overhead: top 10 improvements
#               benchmark                       a                b  gc_overhead_Δ%
# menhir_sysver_canonical trunk-3b14dfbc/baseline pr14571/baseline          -7.365
# sedlex_tokenize_default trunk-3b14dfbc/baseline pr14571/baseline          -7.290
#   test_decompress_large trunk-3b14dfbc/baseline pr14571/baseline          -6.024
#      irmin_mem_rw_large trunk-3b14dfbc/baseline pr14571/baseline          -5.955
#    irmin_mem_rw_default trunk-3b14dfbc/baseline pr14571/baseline          -5.839
#    ydump_repeat_default trunk-3b14dfbc/baseline pr14571/baseline          -5.755
#              jsoo_large trunk-3b14dfbc/baseline pr14571/baseline          -5.530
#   sedlex_tokenize_large trunk-3b14dfbc/baseline pr14571/baseline          -5.405
#      cpdf_squeeze_large trunk-3b14dfbc/baseline pr14571/baseline          -4.810
#    cpdf_squeeze_default trunk-3b14dfbc/baseline pr14571/baseline          -4.673

# %% [markdown]
# ## 5. CSV export
#
# Long-form: one row per (benchmark, comparison-pair) with the median Δ% for the headline metrics. Writes to `cache/regression_report.csv`.

# %%
report_rows = []
metrics_for_report = [
    ("olly_wall_time_s", "wall_Δ%"),
    ("max_rss_mb",       "rss_Δ%"),
    ("olly_gc_overhead_pct", "gc_overhead_Δ%"),
    ("perf_instructions", "instructions_Δ%"),
    ("olly_p95_latency_ms", "p95_latency_Δ%"),
    ("olly_p99_latency_ms", "p99_latency_Δ%"),
]
for cmp in comparisons:
    for av, bv in cmp.pairs:
        per_pair = {
            "comparison": cmp.label,
            "a": av,
            "b": bv,
        }
        per_bench_metric = {}
        for metric, col in metrics_for_report:
            if metric not in df.columns or df[metric].isna().all():
                continue
            d = _delta_per_bench(df, av, bv, metric)
            for bench, v in d.items():
                per_bench_metric.setdefault(bench, {})[col] = round(float(v), 3)
        for bench, mvs in per_bench_metric.items():
            row = {**per_pair, "benchmark": bench}
            row.update(mvs)
            report_rows.append(row)

report = pd.DataFrame(report_rows)
out = Path.cwd() / "cache" / "regression_report.csv"
report.to_csv(out, index=False)
print(f"Wrote {out}  shape={report.shape}")
report.head(10)
# Out:
# Wrote /home/udesou/macro-benches/results/latest/2026-08-18-pr14571-faster-minor-gc-monolith/notebooks/cache/regression_report.csv  shape=(38, 10)
#                                comparison                        a                 b                  benchmark  wall_Δ%  rss_Δ%  gc_overhead_Δ%  \
# 0  faster minor GC PR vs trunk merge-base  trunk-3b14dfbc/baseline  pr14571/baseline     alt_ergo_chain_default   -1.645  -0.008          -4.624
# 1  faster minor GC PR vs trunk merge-base  trunk-3b14dfbc/baseline  pr14571/baseline       alt_ergo_chain_large   -1.232   0.012          -3.202
# 2  faster minor GC PR vs trunk merge-base  trunk-3b14dfbc/baseline  pr14571/baseline          coqc_tree_default    0.158   0.002           0.053
# 3  faster minor GC PR vs trunk merge-base  trunk-3b14dfbc/baseline  pr14571/baseline            coqc_tree_large   -0.959   0.004          -0.052
# 4  faster minor GC PR vs trunk merge-base  trunk-3b14dfbc/baseline  pr14571/baseline       cpdf_squeeze_default   -1.678   0.123          -4.673
# 5  faster minor GC PR vs trunk merge-base  trunk-3b14dfbc/baseline  pr14571/baseline         cpdf_squeeze_large   -3.129   0.093          -4.810
# 6  faster minor GC PR vs trunk merge-base  trunk-3b14dfbc/baseline  pr14571/baseline  devkit_htmlstream_default   -0.202   1.191          -3.093
# 7  faster minor GC PR vs trunk merge-base  trunk-3b14dfbc/baseline  pr14571/baseline    devkit_htmlstream_large    0.213  -5.954          -4.073
# 8  faster minor GC PR vs trunk merge-base  trunk-3b14dfbc/baseline  pr14571/baseline           eio_conc_default   -4.181   0.000          -1.537
# 9  faster minor GC PR vs trunk merge-base  trunk-3b14dfbc/baseline  pr14571/baseline             eio_conc_large   -3.201   0.002          -1.411
#
#    instructions_Δ%  p95_latency_Δ%  p99_latency_Δ%
# 0           -1.924          -2.778          -1.499
# 1           -2.132          -2.459          -0.428
# 2            0.001          -0.116           0.000
# 3           -0.001          -1.547          -0.739
# 4           -3.082          -0.074           0.179
# 5           -1.671           0.831          -0.627
# 6           -0.266          -4.096         -12.510
# 7           -0.199          -2.235         -12.315
# 8           -5.648          -2.068           0.381
# 9           -5.558          -0.630           0.436
